# %%
import pandas as pd

# %%
df = pd.read_json('movie.json')

# %%
df.head()
# Out:
#                       title rating    year  users_rating    votes  metascore  \
# 0   A Rainy Day in New York  PG-13  2019.0           6.6   21,903       44.0
# 1             Murder Manual     18  2020.0           2.4      192        NaN
# 2  Ferris Bueller's Day Off  PG-13  1986.0           7.8  308,847       61.0
# 3                 Cape Fear      R  1991.0           7.3  165,628       73.0
# 4                Mean Girls  PG-13  2004.0           7.0  320,492       66.0
#
#                                              img_url      countries  \
# 0  https://m.media-amazon.com/images/M/MV5BODAwZD...          [USA]
# 1  https://m.media-amazon.com/images/M/MV5BMDI5ZD...          [USA]
# 2  https://m.media-amazon.com/images/M/MV5BMDA0Nj...          [USA]
# 3  https://m.media-amazon.com/images/M/MV5BNjdhNz...          [USA]
# 4  https://m.media-amazon.com/images/M/MV5BMjE1MD...  [USA, Canada]
#
#                                 languages  \
# 0                               [English]
# ...
